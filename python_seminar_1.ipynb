# %% [markdown]
# # 情報活用講座：　材料の劣化と機械学習　実習編
# ### 2023年6月16日

# %% [markdown]
# ## データセット
# Irisデータセットは、統計学や機械学習の分野で広く使用される有名なデータセットです。このデータセットは、植物学の分野で研究されているアヤメ（Iris）の花の特徴に関するデータを含んでいます。
#
# Irisデータセットには、150のサンプルがあり、各サンプルはアヤメの花の特徴を表す4つの数値データで構成されています。これらの特徴は、がく片（sepal）の長さと幅、花びら（petal）の長さと幅を測定したものです。また、各サンプルは3つの異なるアヤメの品種（setosa、versicolor、virginica）に属しています。
#
# Irisデータセットは、分類問題やクラス分類のアルゴリズムの評価や比較などに使用されます。特に、機械学習アルゴリズムの性能や汎化能力を評価するためのベンチマークデータセットとして広く認知されています。
#
# このデータセットは、データの整形や可視化、特徴抽出、モデルのトレーニングなどの様々なデータ処理タスクに使用することができます。また、Irisデータセットは、Pythonの機械学習ライブラリであるScikit-learnなどの多くの機械学習ライブラリで直接利用できるように提供されています。
#
# Irisデータセットは、アヤメの花の特徴に関するデータを通じて、データ解析や機械学習の基礎を学ぶための優れたリソースとなっています。
#
# ![image.png](attachment:image.png)
#
# https://www.embedded-robotics.com/iris-dataset-classification/
#
#
# ## Irisデータセットを使って機械学習を学ぶ目的
#
# Irisデータセットを使用して機械学習を学ぶ目的は、以下のようなものがあります。
#
# 1. **機械学習の基礎理解**: Irisデータセットは非常に有名であり、多くの機械学習の教育教材やチュートリアルで使用されています。このデータセットを通じて、機械学習の基本的な概念や手法を学ぶことができます。
#
# 2. **分類アルゴリズムの学習**: Irisデータセットは、3つの異なるアヤメの品種を分類するためのデータです。このデータセットを使用して、分類アルゴリズム（ロジスティック回帰、決定木、ランダムフォレストなど）を学び、品種の分類を実施することができます。
#
# 3. **特徴選択と次元削減の理解**: Irisデータセットには、4つの特徴が含まれています。これらの特徴を分析し、適切な特徴の選択や次元削減（主成分分析など）を行うことで、モデルのパフォーマンス向上につなげることができます。
#
# 4. **モデル評価とパフォーマンス指標の理解**: Irisデータセットを使用してトレーニングしたモデルを評価し、予測のパフォーマンスを評価することができます。正解率、適合率、再現率、F1スコアなどのパフォーマンス指標を理解し、モデルの性能を評価するスキルを習得することができます。
#
# 5. **データの可視化と解釈**: Irisデータセットは、データの可視化に適しています。特徴の分布や相関関係を可視化することで、データの特性やパターンを理解することができます。また、モデルの解釈や予測結果の説明に役立つ洞察を得ることもできます。
#
# Irisデータセットは、機械学習の初学者や実践者にとって非常に有用なリソースです。
#
#
#
# ## pythonライブラリ
# Pythonプログラミングにおいてライブラリは、再利用可能なコードの集合であり、特定の機能やタスクを実現するための関数やクラスの集まりです。データ処理、可視化、機械学習、ディープラーニングなどの領域で幅広く活用されています。
#
# 1. **NumPy**は、高性能の数値計算やデータ処理に特化したPythonのライブラリです。NumPyは多次元の配列や行列を効率的に操作する機能を提供し、科学技術計算やデータ解析の分野で広く使用されています。
#
# 2. **Pandas**は、データ操作と解析のための高レベルのPythonライブラリです。Pandasは、テーブル形式のデータを効率的に処理し、データのフィルタリング、変換、集約、および結合などの機能を提供します。データの整形やクリーニング、欠損値の処理などを容易に行うことができます。
#
# 3. **Matplotlib**は、Pythonでデータを可視化するための強力なライブラリです。Matplotlibは、グラフや図を描画するための多様な機能を提供し、折れ線グラフ、ヒストグラム、散布図、バーチャートなどの多くのプロットスタイルをサポートしています。データの傾向や関係性を視覚的に理解するための強力なツールです。
#
# 4. **Scikit-learn**は、Pythonで機械学習のタスクを実装するための包括的なライブラリです。Scikit-learnは、分類、回帰、クラスタリング、次元削減などの機械学習アルゴリズムやツールを提供します。データの前処理、特徴抽出、モデルの評価などもサポートしており、機械学習の実装を容易にします。

# %% [markdown]
# # 1.データセットの読み込み

# %% [markdown]
# ### 教材への接続

# %%
# !git clone https://github.com/ARIM-Training/Training_python_1.git
# %cd Training_python_1

# %% [markdown]
# ### ライブラリのインポート

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### サンプルファイルの読み込み
#
# 一般には”開く（Open）”の操作です。pythonではライブラリごとファイルオープンの命令文が異なります。ここではpandasのcsvを読みこむとｋに使うpd.read_csvを使います。
#
# これは、andasライブラリの一部であり、CSV（Comma-Separated Values）ファイルからデータを読み込むための関数です。
#
# pd.read_csvを使用することで、CSVファイルからデータを簡単に読み込み、データの整形や分析、可視化などの処理を行うことができます。これにより、データサイエンスやデータ解析のプロジェクトで、効率的かつ柔軟なデータ処理を行うことができます。

# %%
#データセットの読み込み
df=pd.read_csv("data/iris.csv")

# %%
#データセットの中身を確認しましょう
print (df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. 探索的データ分析（データの俯瞰）

# %% [markdown]
# ## 探索的データ分析（EDA） - データの俯瞰
#
# 探索的データ分析（EDA）は、データのパターン、特徴、関係性を把握し、洞察を得るためにデータを調査し要約するプロセスです。EDAは、データ分析や機械学習プロジェクトにおいて重要なステップです。
#
# ### EDAの目的
#
# EDAの主な目的は次の通りです：
#
# 1. **データの理解**: EDAは、データセットや変数について理解を深めることを支援します。データの構造、内容、品質についての洞察を得ることができます。
#
# 2. **データのパターンと分布の特定**: EDAを使用してデータを探索し、パターン、トレンド、分布を特定します。可視化や統計的な手法を用いて、データが異なる変数間でどのように分布しているかを理解します。
#
# 3. **異常値と外れ値の検出**: EDAは、データセット内の異常値、外れ値、欠損値を特定するのに役立ちます。これにより、データ品質を確保し、データの前処理やクレンジングについての意思決定を行うことができます。
#
# 4. **関係と依存関係の探索**: EDAにより、変数間の関係や依存関係を調査することができます。相関分析、クロス集計、可視化を用いて、データ内の関連や依存関係を特定します。
#
# 5. **特徴量の選択とエンジニアリング**: EDAは、特徴量の選択とエンジニアリングのプロセスを導く洞察を提供します。特徴量間の関係を理解することで、モデリングに最も関連性の高い変数を特定することができます。

# %%
#概要統計: 平均値、中央値、標準偏差、パーセンタイルなどの指標を計算し、変数の中心傾向とばらつきを理解します。
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#　ペアプロットによる各変数間の二次元空間像
sns.pairplot(df)
plt.show()

# %%
#　ペアプロットによる各変数間の二次元空間像
sns.pairplot(df,hue='species')
plt.show()

# %%
#　ペアプロットによる各変数間の二次元空間像
sns.pairplot(df,hue='species',diag_kind='hist')
plt.show()

# %% [markdown]
# # 3.グラフの一例
# setosaからvirginicaについて,それぞれのガクの長さとガクの幅のみのデータセットへと変換します。

# %%
### それぞれの品種でデータセットを分ける
setosa = df.iloc[:50,[0,1]].to_numpy()
versicolor = df.iloc[51:100,[0,1]].to_numpy()
virginica = df.iloc[101:150,[0,1]].to_numpy()

# %% [markdown]
# ### ガク長とガク幅のデータ空間におけるプロット

# %%
fig = plt.figure(figsize=(6,6))
plt.style.use('ggplot')

# 3品種のデータのプロット
plt.plot(setosa[:,0], setosa[:,1], 'o', c='red',alpha=0.5)
plt.plot(versicolor[:,0], versicolor[:,1], 'o', c='blue',alpha=0.5)
plt.plot(virginica[:,0], virginica[:,1], 'o', c='green',alpha=0.5)


# 軸ラベル等
plt.xlabel("Sepal Length (cm)", fontsize =14)
plt.ylabel("Sepal Width (cm)", fontsize =14)
plt.xlim(3,9)
plt.ylim(0, 6)
plt.legend(['setosa','versicolor','virginica','test'], fontsize = 12)

# %% [markdown]
# # 4. scikit-learnによる分析方法の比較

# %% [markdown]
# ## 0.　準備　トレーニングデータとテストデータの分割（クロスバリデーション）

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize

x = df.iloc[0:, 0:4] # 説明変数行列
y = df.iloc[0:, 4]   # 目的変数

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.2,   # CV用データ分割
                                                    stratify = y,       # 均等分割
                                                    random_state=42
                                                    )

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# ## 1. 決定木

# %%
# 決定木
from sklearn.tree import DecisionTreeClassifier

# 決定木モデルによるトレーニング
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %% [markdown]
# ### 訓練データ

# %%
print ("DecisionTreeClassifier training score : {:.3f}".format(model.score(x_train, y_train)))
# Out:
# DecisionTreeClassifier training score : 1.000

# %%
# pandasのcrosstbを使った混同行列の別の表記方法
pd.crosstab(y_pred_train, y_train, margins = True)
# Out:
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               40                0               0   40
# Iris-versicolor            0               40               0   40
# Iris-virginica             0                0              40   40
# All                       40               40              40  120

# %%
# scikit-learnのconfution_matrixを使った混同行列の別の表記方法
from sklearn import metrics
print(metrics.confusion_matrix(y_pred_train, y_train))
# Out:
# [[40  0  0]
#  [ 0 40  0]
#  [ 0  0 40]]

# %%
# Precision Recall scores
print(metrics.classification_report(y_pred_train, y_train, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        40
# Iris-versicolor      1.000     1.000     1.000        40
#  Iris-virginica      1.000     1.000     1.000        40
#
#        accuracy                          1.000       120
#       macro avg      1.000     1.000     1.000       120
#    weighted avg      1.000     1.000     1.000       120

# %% [markdown]
# ### テストデータ

# %%
print ("DecisionTreeClassifier test score : {:.3f}".format(model.score(x_test, y_test)))
# Out:
# DecisionTreeClassifier test score : 0.933

# %%
pd.crosstab(y_pred_test, y_test, margins = True)
# Out:
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               10                0               0   10
# Iris-versicolor            0                9               1   10
# Iris-virginica             0                1               9   10
# All                       10               10              10   30

# %%
print(metrics.confusion_matrix(y_pred_test, y_test))
# Out:
# [[10  0  0]
#  [ 0  9  1]
#  [ 0  1  9]]

# %%
# Precision Recall scores
print(metrics.classification_report(y_pred_test, y_test, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        10
# Iris-versicolor      0.900     0.900     0.900        10
#  Iris-virginica      0.900     0.900     0.900        10
#
#        accuracy                          0.933        30
#       macro avg      0.933     0.933     0.933        30
#    weighted avg      0.933     0.933     0.933        30

# %% [markdown]
# ## 2. ランダムフォレスト

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)   

y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %% [markdown]
# ### 訓練データ

# %%
print ("DecisionTreeClassifier training score : {:.3f}".format(model.score(x_train, y_train)))
pd.crosstab(y_pred_train, y_train, margins = True)
# Out:
# DecisionTreeClassifier training score : 1.000
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               40                0               0   40
# Iris-versicolor            0               40               0   40
# Iris-virginica             0                0              40   40
# All                       40               40              40  120

# %%
print(metrics.classification_report(y_pred_train, y_train, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        40
# Iris-versicolor      1.000     1.000     1.000        40
#  Iris-virginica      1.000     1.000     1.000        40
#
#        accuracy                          1.000       120
#       macro avg      1.000     1.000     1.000       120
#    weighted avg      1.000     1.000     1.000       120

# %% [markdown]
# ### テストデータ

# %%
print ("DecisionTreeClassifier test score : {:.3f}".format(model.score(x_test, y_test)))
pd.crosstab(y_pred_test, y_test, margins = True)
# Out:
# DecisionTreeClassifier test score : 0.933
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               10                0               0   10
# Iris-versicolor            0                9               1   10
# Iris-virginica             0                1               9   10
# All                       10               10              10   30

# %%
# Precision Recall scores
print(metrics.classification_report(y_pred_test, y_test, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        10
# Iris-versicolor      0.900     0.900     0.900        10
#  Iris-virginica      0.900     0.900     0.900        10
#
#        accuracy                          0.933        30
#       macro avg      0.933     0.933     0.933        30
#    weighted avg      0.933     0.933     0.933        30

# %% [markdown]
# ## 3.サポートベクターマシーン

# %%
# サポートベクター
from sklearn.svm import SVC

model = SVC()
model.fit(x_train, y_train)   

y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %% [markdown]
# ### 訓練データ

# %%
print ("SupportVectorClassifier training score : {:,.3f}".format(model.score(x_train, y_train)))
pd.crosstab(y_pred_train, y_train, margins = True)
# Out:
# SupportVectorClassifier training score : 0.983
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               40                0               0   40
# Iris-versicolor            0               39               1   40
# Iris-virginica             0                1              39   40
# All                       40               40              40  120

# %%
print(metrics.classification_report(y_pred_train, y_train, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        40
# Iris-versicolor      0.975     0.975     0.975        40
#  Iris-virginica      0.975     0.975     0.975        40
#
#        accuracy                          0.983       120
#       macro avg      0.983     0.983     0.983       120
#    weighted avg      0.983     0.983     0.983       120

# %% [markdown]
# ### テストデータ

# %%
print ("SupportVectorClassifier test score : {:,.3f}".format(model.score(x_test, y_test)))
pd.crosstab(y_pred_test, y_test, margins = True)
# Out:
# SupportVectorClassifier test score : 0.967
# species          Iris-setosa  Iris-versicolor  Iris-virginica  All
# row_0
# Iris-setosa               10                0               0   10
# Iris-versicolor            0                9               0    9
# Iris-virginica             0                1              10   11
# All                       10               10              10   30

# %%
# Precision Recall scores
print(metrics.classification_report(y_pred_test, y_test, digits=3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa      1.000     1.000     1.000        10
# Iris-versicolor      0.900     1.000     0.947         9
#  Iris-virginica      1.000     0.909     0.952        11
#
#        accuracy                          0.967        30
#       macro avg      0.967     0.970     0.967        30
#    weighted avg      0.970     0.967     0.967        30

# %% [markdown]
# ## 4.主成分分析

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# データの標準化
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# PCAの実行
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# 主成分の寄与率を取得
explained_variance_ratio = pca.explained_variance_ratio_

print (explained_variance_ratio)
# Out:
# [0.72962445 0.22850762]

# %%
# 結果のプロット
plt.figure(figsize=(7, 6))
colors = ['blue', 'red', 'green']

for target, color in zip(np.unique(y), colors):
    plt.scatter(X_pca[y == target, 0], X_pca[y == target, 1], 
                color=color, 
                label=f'Class {target}')
    
plt.xlabel('PC1 ({:.2f}% explained variance)'.format(explained_variance_ratio[0] * 100))
plt.ylabel('PC2 ({:.2f}% explained variance)'.format(explained_variance_ratio[1] * 100))

plt.legend()
plt.show()

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object
